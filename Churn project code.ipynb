# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("customer_churn.db")
print("Connected successfully!")
# Out:
# Connected successfully!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
sql_query = """
        select name 
        from sqlite_master
        where type ='table';

"""

tables = pd.read_sql(sql_query,conn)

for table_name in tables['name']:
    df=pd.read_sql(f"select * from {table_name}",conn)
    globals()[f"df_{table_name}"]= df
    print(f"created dataframe : df_{table_name}")
    
conn.close()
# Out:
# created dataframe : df_db_customer
# created dataframe : df_db_subscription
# created dataframe : df_db_support

# %%
df_db_customer.head()
# Out:
#    customerid    name country        state  gender                  dob  \
# 0  0002-ORFBO  keshav   India  Maharashtra    Male  1982-04-12 00:00:00
# 1  0003-MKNFE  raghav   India    Karnataka    Male  1995-11-23 00:00:00
# 2  0004-TLHLJ  lalita   India        Delhi  Female  1978-02-15 00:00:00
# 3  0011-IGKFF   mohan   India     Nagaland    Male  2001-08-30 00:00:00
# 4  0013-EXCHZ    mira   India        Delhi  Female  1990-05-05 00:00:00
#
#   interests pincode
# 0    travel    None
# 1      None    None
# 2     movie    None
# 3      None    None
# 4     drama    None

# %%
df_db_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  21 non-null     object
#  1   name        21 non-null     object
#  2   country     18 non-null     object
#  3   state       21 non-null     object
#  4   gender      21 non-null     object
#  5   dob         21 non-null     object
#  6   interests   4 non-null      object
#  7   pincode     0 non-null      object
# dtypes: object(8)
# memory usage: 1.4+ KB

# %%
df_db_customer.tail(
    
)
# Out:
#     customerid        name country          state  gender  \
# 16  0020-JDNXP       rikim   India      Meghalaya  Female
# 17  0021-IKXGC    vishakha   India      Rajasthan  Female
# 18  0022-TCJCI  raghvendra   India      Telangana    Male
# 19  0023-HGHWL     rishabh   India  Uttar Pradesh     Men
# 20  0023-UYUPN      sudevi   India    Maharashtra   Women
#
#                     dob interests pincode
# 16  1994-08-19 00:00:00      None    None
# 17  2000-09-02 00:00:00      None    None
# 18  1983-12-30 00:00:00      None    None
# 19  1991-05-14 00:00:00      None    None
# 20  1977-10-06 00:00:00      None    None

# %%
df_db_customer.rename(columns={'name': 'customer_name'},inplace=True)

# %%
 df_db_customer.drop(df_db_customer.columns[-2:],axis=1, inplace=True)

# %%
 df_db_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     21 non-null     object
#  1   customer_name  21 non-null     object
#  2   country        18 non-null     object
#  3   state          21 non-null     object
#  4   gender         21 non-null     object
#  5   dob            21 non-null     object
# dtypes: object(6)
# memory usage: 1.1+ KB

# %%
df_db_customer['dob']=pd.to_datetime( df_db_customer['dob'])

# %%
df_db_customer['gender'].unique()
df_db_customer['gender']=df_db_customer['gender'].replace({'Men': 'Male','Women': 'Female'})

# %%
df_db_customer[df_db_customer['country'].isna()]
# Out:
#     customerid customer_name country      state  gender        dob
# 5   0013-MHZWF         durga    None      Delhi  Female 1988-12-10
# 8   0015-UOCOJ          maya    None  Kathmandu  Female 1985-07-07
# 12  0018-NYROU        chitra    None  Telangana  Female 2004-12-01

# %%
df_db_customer[['country','state']]
# Out:
#    country          state
# 0    India    Maharashtra
# 1    India      Karnataka
# 2    India          Delhi
# 3    India       Nagaland
# 4    India          Delhi
# 5     None          Delhi
# 6    India      Meghalaya
# 7    India      Rajasthan
# 8     None      Kathmandu
# 9    Nepal      Kathmandu
# 10   India    Maharashtra
# 11   India      Karnataka
# 12    None      Telangana
# 13   India      Meghalaya
# 14   India  Uttar Pradesh
# 15   India          Delhi
# 16   India      Meghalaya
# 17   India      Rajasthan
# 18   India      Telangana
# 19   India  Uttar Pradesh
# 20   India    Maharashtra

# %%
state_country_mapping=df_db_customer.dropna(subset=['country']).set_index('state')['country'].to_dict()

# %%
df_db_customer['country']=df_db_customer['country'].fillna(df_db_customer['state'].map(state_country_mapping))

# %%
df_db_customer['country'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: country, dtype: bool

# %%
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual              None                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly              None                    None
# 3   Premium        Annual              None                    None
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score
# 0            13.99   627           12
# 1            12.99  1150           91
# 2             6.99   210           34
# 3            22.99  1725            8
# 4            13.99   195           88

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     object
#  1   subscription_start_date  21 non-null     object
#  2   subscription_type        21 non-null     object
#  3   renewal_date             21 non-null     object
#  4   plan_type                21 non-null     object
#  5   contract_type            21 non-null     object
#  6   cancellation_date        6 non-null      object
#  7   cancellation_reason      6 non-null      object
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.9+ KB

# %%
date_col=['subscription_start_date','renewal_date','cancellation_date']

# %%
df_db_subscription[date_col]=df_db_subscription[date_col].apply(pd.to_datetime)

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     object
#  1   subscription_start_date  21 non-null     datetime64[ns]
#  2   subscription_type        21 non-null     object
#  3   renewal_date             21 non-null     datetime64[ns]
#  4   plan_type                21 non-null     object
#  5   contract_type            21 non-null     object
#  6   cancellation_date        6 non-null      datetime64[ns]
#  7   cancellation_reason      6 non-null      object
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: datetime64[ns](3), float64(1), int64(2), object(5)
# memory usage: 1.9+ KB

# %%
df_db_support.head()
# Out:
#    customerid       complaint_date escalations  csat_score col_1  \
# 0  0003-MKNFE  2024-08-28 00:00:00           N          60  None
# 1  0003-MKNFE  2024-08-28 00:00:00           Y          10  None
# 2  0013-EXCHZ  2024-01-20 00:00:00           Y          20  None
# 3  0013-MHZWF  2025-03-18 00:00:00           N          90  None
# 4  0013-SMEOE  2024-11-01 00:00:00           N          30  None
#
#              comment
# 0      service issue
# 1     demaned refund
# 2               None
# 3  guidance to renew
# 4               None

# %%
df_db_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      object
#  1   complaint_date  9 non-null      object
#  2   escalations     9 non-null      object
#  3   csat_score      9 non-null      int64
#  4   col_1           0 non-null      object
#  5   comment         4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 564.0+ bytes

# %%
df_db_support.drop(columns=['col_1','comment'],inplace =True)

# %%
df_db_support['complaint_date']=pd.to_datetime(df_db_support['complaint_date'])

# %%
df_db_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      object
#  1   complaint_date  9 non-null      datetime64[ns]
#  2   escalations     9 non-null      object
#  3   csat_score      9 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 420.0+ bytes

# %%
df_db_subscription['churn_flag']=np.where(df_db_subscription['cancellation_date'].notna(),1,0)

# %%
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                    None
# 3   Premium        Annual               NaT                    None
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score  churn_flag
# 0            13.99   627           12           0
# 1            12.99  1150           91           1
# 2             6.99   210           34           0
# 3            22.99  1725            8           0
# 4            13.99   195           88           1

# %%
df = (df_db_subscription
    .merge(df_db_customer , on ='customerid',how='left')
    .merge(df_db_support , on ='customerid',how='left'))

# %%
df
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 3   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 4   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 5   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 6   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 7   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 8   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 9   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 10  0016-QLJIS              2022-04-03           Organic   2025-04-03
# 11  0017-DINOC              2021-12-01           Organic   2025-12-01
# 12  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# 13  0018-NYROU              2020-10-09           Organic   2025-10-09
# 14  0019-EFAEP              2022-08-25          Refferal   2024-08-25
# 15  0019-GFNTW              2019-11-11              Paid   2025-11-11
# 16  0020-INWCK              2023-05-06           Organic   2025-05-06
# 17  0020-JDNXP              2022-01-19           Organic   2024-01-19
# 18  0021-IKXGC              2021-07-07              Paid   2025-07-07
# 19  0022-TCJCI              2023-09-14          Refferal   2024-09-14
# 20  0022-TCJCI              2023-09-14          Refferal   2024-09-14
# 21  0023-HGHWL              2020-06-23           Organic   2025-06-23
# 22  0023-UYUPN              2022-12-31              Paid   2025-12-31
#
#    plan_type contract_type cancellation_date     cancellation_reason  \
# 0   Standard        Annual               NaT                    None
# 1    Premium        Annual        2024-09-10  Switched to competitor
# 2    Premium        Annual        2024-09-10  Switched to competitor
# 3      Basic       Monthly               NaT                    None
# 4    Premium        Annual               NaT                    None
# 5   Standard       Monthly        2024-02-28           Too expensive
# 6   Standard        Annual               NaT                    None
# 7      Basic       Monthly        2024-11-15      Not enough content
# 8    Premium        Annual               NaT                    None
# 9   Standard       Monthly               NaT                    None
# 10     Basic        Annual               NaT                    None
# 11   Premium        Annual               NaT                    None
# 12  Standard       Monthly        2024-05-01  Poor streaming quality
# 13  Standard        Annual               NaT                    None
# 14     Basic       Monthly        2024-10-31  Switched to competitor
# 15   Premium        Annual               NaT                    None
# 16  Standard       Monthly               NaT                    None
# 17   Premium        Annual               NaT                    None
# 18  Standard        Annual               NaT                    None
# 19     Basic       Monthly        2024-09-14  Forgot to cancel trial
# 20     Basic       Monthly        2024-09-14  Forgot to cancel trial
# 21   Premium        Annual               NaT                    None
# 22  Standard       Monthly               NaT                    None
#
#     monthly_charges  cltv  churn_score  churn_flag customer_name country  \
# 0             13.99   627           12           0        keshav   India
# 1             12.99  1150           91           1        raghav   India
# 2             12.99  1150           91           1        raghav   India
# 3              6.99   210           34           0        lalita   India
# 4             22.99  1725            8           0         mohan   India
# 5             13.99   195           88           1          mira   India
# 6             17.99   720           22           0         durga   India
# 7              8.99   230           79           1          mina   India
# 8             22.99  1840            5           0         madan   India
# 9             13.99   240           34           0          maya   Nepal
# 10             6.99   335           41           0         arjun   Nepal
# 11            22.99  1610           14           0         shiva   India
# 12             7.99   270           83           1     rangadevi   India
# 13            13.99   980           19           0        chitra   India
# 14            12.99   160           76           1          raju   India
# 15            92.99  2185            3           0        Madhav   India
# 16            13.99   640           58           0       parvati   India
# 17            20.99   550           62           0         rikim   India
# 18            13.99   840           27           0      vishakha   India
# 19            16.99    42           99           1    raghvendra   India
# 20            16.99    42           99           1    raghvendra   India
# 21            22.99  1955            7           0       rishabh   India
# 22            13.99   790           47           0        sudevi   India
#
#             state  gender        dob complaint_date escalations  csat_score
# 0     Maharashtra    Male 1982-04-12            NaT         NaN         NaN
# 1       Karnataka    Male 1995-11-23     2024-08-28           N        60.0
# 2       Karnataka    Male 1995-11-23     2024-08-28           Y        10.0
# 3           Delhi  Female 1978-02-15            NaT         NaN         NaN
# 4        Nagaland    Male 2001-08-30            NaT         NaN         NaN
# 5           Delhi  Female 1990-05-05     2024-01-20           Y        20.0
# 6           Delhi  Female 1988-12-10     2025-03-18           N        90.0
# 7       Meghalaya  Female 1976-09-21     2024-11-01           N        30.0
# 8       Rajasthan    Male 1999-03-14            NaT         NaN         NaN
# 9       Kathmandu  Female 1985-07-07            NaT         NaN         NaN
# 10      Kathmandu    Male 1993-10-29            NaT         NaN         NaN
# 11    Maharashtra    Male 1997-01-22            NaT         NaN         NaN
# 12      Karnataka  Female 1981-06-18     2024-04-10           Y        25.0
# 13      Telangana  Female 2004-12-01            NaT         NaN         NaN
# 14      Meghalaya  Female 1992-04-25     2024-09-27           Y        30.0
# 15  Uttar Pradesh    Male 1979-11-11            NaT         NaN         NaN
# 16          Delhi  Female 1986-02-28            NaT         NaN         NaN
# 17      Meghalaya  Female 1994-08-19            NaT         NaN         NaN
# 18      Rajasthan  Female 2000-09-02            NaT         NaN         NaN
# 19      Telangana    Male 1983-12-30     2024-09-13           Y        10.0
# 20      Telangana    Male 1983-12-30     2024-09-14           N        90.0
# 21  Uttar Pradesh    Male 1991-05-14            NaT         NaN         NaN
# 22    Maharashtra  Female 1977-10-06            NaT         NaN         NaN

# %%
df.shape
# Out:
# (23, 20)

# %%
df_db_support['complaint_count']=df_db_support.groupby('customerid')['customerid'].transform('count')

# %%
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score  complaint_count
# 0  0003-MKNFE     2024-08-28           N          60                2
# 1  0003-MKNFE     2024-08-28           Y          10                2
# 2  0013-EXCHZ     2024-01-20           Y          20                1
# 3  0013-MHZWF     2025-03-18           N          90                1
# 4  0013-SMEOE     2024-11-01           N          30                1
# 5  0017-IUDMW     2024-04-10           Y          25                1
# 6  0019-EFAEP     2024-09-27           Y          30                1
# 7  0022-TCJCI     2024-09-13           Y          10                2
# 8  0022-TCJCI     2024-09-14           N          90                2

# %%
df_db_support=df_db_support.sort_values('complaint_date').drop_duplicates('customerid',keep='last')

# %%
df = (df_db_subscription
    .merge(df_db_customer , on ='customerid',how='left')
    .merge(df_db_support , on ='customerid',how='left'))

# %%
df.shape
# Out:
# (21, 21)

# %%
df
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 5   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 6   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 7   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 8   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 9   0016-QLJIS              2022-04-03           Organic   2025-04-03
# 10  0017-DINOC              2021-12-01           Organic   2025-12-01
# 11  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# 12  0018-NYROU              2020-10-09           Organic   2025-10-09
# 13  0019-EFAEP              2022-08-25          Refferal   2024-08-25
# 14  0019-GFNTW              2019-11-11              Paid   2025-11-11
# 15  0020-INWCK              2023-05-06           Organic   2025-05-06
# 16  0020-JDNXP              2022-01-19           Organic   2024-01-19
# 17  0021-IKXGC              2021-07-07              Paid   2025-07-07
# 18  0022-TCJCI              2023-09-14          Refferal   2024-09-14
# 19  0023-HGHWL              2020-06-23           Organic   2025-06-23
# 20  0023-UYUPN              2022-12-31              Paid   2025-12-31
#
#    plan_type contract_type cancellation_date     cancellation_reason  \
# 0   Standard        Annual               NaT                    None
# 1    Premium        Annual        2024-09-10  Switched to competitor
# 2      Basic       Monthly               NaT                    None
# 3    Premium        Annual               NaT                    None
# 4   Standard       Monthly        2024-02-28           Too expensive
# 5   Standard        Annual               NaT                    None
# 6      Basic       Monthly        2024-11-15      Not enough content
# 7    Premium        Annual               NaT                    None
# 8   Standard       Monthly               NaT                    None
# 9      Basic        Annual               NaT                    None
# 10   Premium        Annual               NaT                    None
# 11  Standard       Monthly        2024-05-01  Poor streaming quality
# 12  Standard        Annual               NaT                    None
# 13     Basic       Monthly        2024-10-31  Switched to competitor
# 14   Premium        Annual               NaT                    None
# 15  Standard       Monthly               NaT                    None
# 16   Premium        Annual               NaT                    None
# 17  Standard        Annual               NaT                    None
# 18     Basic       Monthly        2024-09-14  Forgot to cancel trial
# 19   Premium        Annual               NaT                    None
# 20  Standard       Monthly               NaT                    None
#
#     monthly_charges  cltv  ...  churn_flag  customer_name country  \
# 0             13.99   627  ...           0         keshav   India
# 1             12.99  1150  ...           1         raghav   India
# 2              6.99   210  ...           0         lalita   India
# 3             22.99  1725  ...           0          mohan   India
# 4             13.99   195  ...           1           mira   India
# 5             17.99   720  ...           0          durga   India
# 6              8.99   230  ...           1           mina   India
# 7             22.99  1840  ...           0          madan   India
# 8             13.99   240  ...           0           maya   Nepal
# 9              6.99   335  ...           0          arjun   Nepal
# 10            22.99  1610  ...           0          shiva   India
# 11             7.99   270  ...           1      rangadevi   India
# 12            13.99   980  ...           0         chitra   India
# 13            12.99   160  ...           1           raju   India
# 14            92.99  2185  ...           0         Madhav   India
# 15            13.99   640  ...           0        parvati   India
# 16            20.99   550  ...           0          rikim   India
# 17            13.99   840  ...           0       vishakha   India
# 18            16.99    42  ...           1     raghvendra   India
# 19            22.99  1955  ...           0        rishabh   India
# 20            13.99   790  ...           0         sudevi   India
#
#             state  gender        dob complaint_date escalations csat_score  \
# 0     Maharashtra    Male 1982-04-12            NaT         NaN        NaN
# 1       Karnataka    Male 1995-11-23     2024-08-28           Y       10.0
# 2           Delhi  Female 1978-02-15            NaT         NaN        NaN
# 3        Nagaland    Male 2001-08-30            NaT         NaN        NaN
# 4           Delhi  Female 1990-05-05     2024-01-20           Y       20.0
# 5           Delhi  Female 1988-12-10     2025-03-18           N       90.0
# 6       Meghalaya  Female 1976-09-21     2024-11-01           N       30.0
# 7       Rajasthan    Male 1999-03-14            NaT         NaN        NaN
# 8       Kathmandu  Female 1985-07-07            NaT         NaN        NaN
# 9       Kathmandu    Male 1993-10-29            NaT         NaN        NaN
# 10    Maharashtra    Male 1997-01-22            NaT         NaN        NaN
# 11      Karnataka  Female 1981-06-18     2024-04-10           Y       25.0
# 12      Telangana  Female 2004-12-01            NaT         NaN        NaN
# 13      Meghalaya  Female 1992-04-25     2024-09-27           Y       30.0
# 14  Uttar Pradesh    Male 1979-11-11            NaT         NaN        NaN
# 15          Delhi  Female 1986-02-28            NaT         NaN        NaN
# 16      Meghalaya  Female 1994-08-19            NaT         NaN        NaN
# 17      Rajasthan  Female 2000-09-02            NaT         NaN        NaN
# 18      Telangana    Male 1983-12-30     2024-09-14           N       90.0
# 19  Uttar Pradesh    Male 1991-05-14            NaT         NaN        NaN
# 20    Maharashtra  Female 1977-10-06            NaT         NaN        NaN
#
#     complaint_count
# 0               NaN
# 1               2.0
# 2               NaN
# 3               NaN
# 4               1.0
# 5               1.0
# 6               1.0
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              1.0
# 12              NaN
# 13              1.0
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              2.0
# 19              NaN
# 20              NaN
#
# [21 rows x 21 columns]

# %%
df.to_csv('exported_churn_data.csv',index=False)

# %%
#Data Analysis

# %%
df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count'],
#       dtype='object')

# %%
churn_rate=df['churn_flag'].mean()*100
print("Churn Rate = ", round(churn_rate,2), "%")
# Out:
# Churn Rate =  28.57 %

# %%
#retention rate

# %%
retention_rate = 100 - churn_rate

# %%
retention_rate
# Out:
# np.float64(71.42857142857143)

# %%
df.head(2)
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
#
#    monthly_charges  cltv  ...  churn_flag  customer_name country        state  \
# 0            13.99   627  ...           0         keshav   India  Maharashtra
# 1            12.99  1150  ...           1         raghav   India    Karnataka
#
#   gender        dob complaint_date escalations csat_score  complaint_count
# 0   Male 1982-04-12            NaT         NaN        NaN              NaN
# 1   Male 1995-11-23     2024-08-28           Y       10.0              2.0
#
# [2 rows x 21 columns]

# %%
churn_by_plan =df.groupby('plan_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct')

# %%
churn_by_plan
# Out:
#   plan_type  churn_rate_pct
# 0     Basic           60.00
# 1   Premium           14.29
# 2  Standard           22.22

# %%
churn_by_state =df.groupby('state')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct')

# %%
churn_by_state
# Out:
#            state  churn_rate_pct
# 0          Delhi           25.00
# 1      Karnataka          100.00
# 2      Kathmandu            0.00
# 3    Maharashtra            0.00
# 4      Meghalaya           66.67
# 5       Nagaland            0.00
# 6      Rajasthan            0.00
# 7      Telangana           50.00
# 8  Uttar Pradesh            0.00

# %%
churn_by_subtype =df.groupby('subscription_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct')

# %%
churn_by_state =df.groupby('state')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct')

# %%
churn_by_state
# Out:
#            state  churn_rate_pct
# 0          Delhi           25.00
# 1      Karnataka          100.00
# 2      Kathmandu            0.00
# 3    Maharashtra            0.00
# 4      Meghalaya           66.67
# 5       Nagaland            0.00
# 6      Rajasthan            0.00
# 7      Telangana           50.00
# 8  Uttar Pradesh            0.00

# %%
churn_by_subtype
# Out:
#   subscription_type  churn_rate_pct
# 0           Organic            0.00
# 1              Paid           16.67
# 2          Refferal           83.33

# %%
#ARPU- avg revenue per user

# %%
arpu = df['monthly_charges'].mean()

# %%
arpu
# Out:
# np.float64(18.847142857142856)

# %%
today=pd.Timestamp.today()
today
# Out:
# Timestamp('2026-07-24 03:21:28.656787')

# %%
df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
#
#    monthly_charges  cltv  ...  churn_flag  customer_name country        state  \
# 0            13.99   627  ...           0         keshav   India  Maharashtra
# 1            12.99  1150  ...           1         raghav   India    Karnataka
#
#   gender        dob complaint_date escalations csat_score  complaint_count
# 0   Male 1982-04-12            NaT         NaN        NaN              NaN
# 1   Male 1995-11-23     2024-08-28           Y       10.0              2.0
#
# [2 rows x 21 columns]

# %%
df['tenure_days']=np.where(
    df['cancellation_date'].notna(),
    (df['cancellation_date']-df['subscription_start_date']).dt.days,

    (today-df['subscription_start_date']).dt.days
    
)

# %%
df.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                    None
# 3   Premium        Annual               NaT                    None
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  ...  customer_name  country        state  gender  \
# 0            13.99   627  ...         keshav    India  Maharashtra    Male
# 1            12.99  1150  ...         raghav    India    Karnataka    Male
# 2             6.99   210  ...         lalita    India        Delhi  Female
# 3            22.99  1725  ...          mohan    India     Nagaland    Male
# 4            13.99   195  ...           mira    India        Delhi  Female
#
#          dob complaint_date escalations csat_score complaint_count  \
# 0 1982-04-12            NaT         NaN        NaN             NaN
# 1 1995-11-23     2024-08-28           Y       10.0             2.0
# 2 1978-02-15            NaT         NaN        NaN             NaN
# 3 2001-08-30            NaT         NaN        NaN             NaN
# 4 1990-05-05     2024-01-20           Y       20.0             1.0
#
#    tenure_days
# 0       1957.0
# 1       1501.0
# 2       1342.0
# 3       2632.0
# 4        419.0
#
# [5 rows x 22 columns]

# %%
avg_tenure = df['tenure_days'].mean()

# %%
avg_tenure
# Out:
# np.float64(1501.5714285714287)

# %%
revenue_at_risk=df.loc[df['churn_flag']==1,'monthly_charges'].sum()

# %%
revenue_at_risk
# Out:
# np.float64(73.94)

# %%
# escalation rate

# %%
escalation_rate=(df['escalations']=='Y').mean()*100

# %%
escalation_rate
# Out:
# np.float64(19.047619047619047)

# %%
#avg complaint rate per user

# %%
avg_complaints = df['complaint_count'].sum()/df['customerid'].nunique()

# %%
avg_complaints
print("avg complaint per user = ",round(avg_complaints,2))
# Out:
# avg complaint per user =  0.43

# %%
# correlation escalation vs churn

# %%
df[['customerid','escalations','churn_flag']].dropna()
df['escalations']= np.where(df['escalations']=='Y',1,0)

# %%
corr_df=df[['escalations','churn_flag']].dropna()

# %%
correlation =corr_df['escalations'].corr(df['churn_flag'])

# %%
correlation
print("correlation bw eescalations and churn is = ",round(correlation,2))
# Out:
# correlation bw eescalations and churn is =  0.77

# %%
#churn risk - create a column using existing columnn

# %%
conditions = [
        (df['churn_score']<50),
        ((df['churn_score']>=50) & (df['churn_score']<70)),
        (df['churn_score']>=70)
]

choices = ['low','med','high']


df['churn_risk'] = np.select(conditions, choices , default = 'unknown')

# %%
df[['churn_risk','churn_score']].head()
# Out:
#   churn_risk  churn_score
# 0        low           12
# 1       high           91
# 2        low           34
# 3        low            8
# 4       high           88

# %%
# visualisation using matplotlib and seaborn

# %%
df_visual=df.copy()

# %%
df_visual
# Out:
#     customerid subscription_start_date subscription_type renewal_date  \
# 0   0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1   0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2   0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3   0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4   0013-EXCHZ              2023-01-05          Refferal   2024-01-05
# 5   0013-MHZWF              2022-06-18              Paid   2025-06-18
# 6   0013-SMEOE              2021-09-30          Refferal   2024-09-30
# 7   0014-BMAQU              2020-02-14           Organic   2025-02-14
# 8   0015-UOCOJ              2023-07-22           Organic   2024-07-22
# 9   0016-QLJIS              2022-04-03           Organic   2025-04-03
# 10  0017-DINOC              2021-12-01           Organic   2025-12-01
# 11  0017-IUDMW              2023-03-17          Refferal   2024-03-17
# 12  0018-NYROU              2020-10-09           Organic   2025-10-09
# 13  0019-EFAEP              2022-08-25          Refferal   2024-08-25
# 14  0019-GFNTW              2019-11-11              Paid   2025-11-11
# 15  0020-INWCK              2023-05-06           Organic   2025-05-06
# 16  0020-JDNXP              2022-01-19           Organic   2024-01-19
# 17  0021-IKXGC              2021-07-07              Paid   2025-07-07
# 18  0022-TCJCI              2023-09-14          Refferal   2024-09-14
# 19  0023-HGHWL              2020-06-23           Organic   2025-06-23
# 20  0023-UYUPN              2022-12-31              Paid   2025-12-31
#
#    plan_type contract_type cancellation_date     cancellation_reason  \
# 0   Standard        Annual               NaT                    None
# 1    Premium        Annual        2024-09-10  Switched to competitor
# 2      Basic       Monthly               NaT                    None
# 3    Premium        Annual               NaT                    None
# 4   Standard       Monthly        2024-02-28           Too expensive
# 5   Standard        Annual               NaT                    None
# 6      Basic       Monthly        2024-11-15      Not enough content
# 7    Premium        Annual               NaT                    None
# 8   Standard       Monthly               NaT                    None
# 9      Basic        Annual               NaT                    None
# 10   Premium        Annual               NaT                    None
# 11  Standard       Monthly        2024-05-01  Poor streaming quality
# 12  Standard        Annual               NaT                    None
# 13     Basic       Monthly        2024-10-31  Switched to competitor
# 14   Premium        Annual               NaT                    None
# 15  Standard       Monthly               NaT                    None
# 16   Premium        Annual               NaT                    None
# 17  Standard        Annual               NaT                    None
# 18     Basic       Monthly        2024-09-14  Forgot to cancel trial
# 19   Premium        Annual               NaT                    None
# 20  Standard       Monthly               NaT                    None
#
#     monthly_charges  cltv  ...  country          state  gender        dob  \
# 0             13.99   627  ...    India    Maharashtra    Male 1982-04-12
# 1             12.99  1150  ...    India      Karnataka    Male 1995-11-23
# 2              6.99   210  ...    India          Delhi  Female 1978-02-15
# 3             22.99  1725  ...    India       Nagaland    Male 2001-08-30
# 4             13.99   195  ...    India          Delhi  Female 1990-05-05
# 5             17.99   720  ...    India          Delhi  Female 1988-12-10
# 6              8.99   230  ...    India      Meghalaya  Female 1976-09-21
# 7             22.99  1840  ...    India      Rajasthan    Male 1999-03-14
# 8             13.99   240  ...    Nepal      Kathmandu  Female 1985-07-07
# 9              6.99   335  ...    Nepal      Kathmandu    Male 1993-10-29
# 10            22.99  1610  ...    India    Maharashtra    Male 1997-01-22
# 11             7.99   270  ...    India      Karnataka  Female 1981-06-18
# 12            13.99   980  ...    India      Telangana  Female 2004-12-01
# 13            12.99   160  ...    India      Meghalaya  Female 1992-04-25
# 14            92.99  2185  ...    India  Uttar Pradesh    Male 1979-11-11
# 15            13.99   640  ...    India          Delhi  Female 1986-02-28
# 16            20.99   550  ...    India      Meghalaya  Female 1994-08-19
# 17            13.99   840  ...    India      Rajasthan  Female 2000-09-02
# 18            16.99    42  ...    India      Telangana    Male 1983-12-30
# 19            22.99  1955  ...    India  Uttar Pradesh    Male 1991-05-14
# 20            13.99   790  ...    India    Maharashtra  Female 1977-10-06
#
#    complaint_date escalations csat_score complaint_count  tenure_days  \
# 0             NaT           0        NaN             NaN       1957.0
# 1      2024-08-28           1       10.0             2.0       1501.0
# 2             NaT           0        NaN             NaN       1342.0
# 3             NaT           0        NaN             NaN       2632.0
# 4      2024-01-20           1       20.0             1.0        419.0
# 5      2025-03-18           0       90.0             1.0       1497.0
# 6      2024-11-01           0       30.0             1.0       1142.0
# 7             NaT           0        NaN             NaN       2352.0
# 8             NaT           0        NaN             NaN       1098.0
# 9             NaT           0        NaN             NaN       1573.0
# 10            NaT           0        NaN             NaN       1696.0
# 11     2024-04-10           1       25.0             1.0        411.0
# 12            NaT           0        NaN             NaN       2114.0
# 13     2024-09-27           1       30.0             1.0        798.0
# 14            NaT           0        NaN             NaN       2447.0
# 15            NaT           0        NaN             NaN       1175.0
# 16            NaT           0        NaN             NaN       1647.0
# 17            NaT           0        NaN             NaN       1843.0
# 18     2024-09-14           0       90.0             2.0        366.0
# 19            NaT           0        NaN             NaN       2222.0
# 20            NaT           0        NaN             NaN       1301.0
#
#     churn_risk
# 0          low
# 1         high
# 2          low
# 3          low
# 4         high
# 5          low
# 6         high
# 7          low
# 8          low
# 9          low
# 10         low
# 11        high
# 12         low
# 13        high
# 14         low
# 15         med
# 16         med
# 17         low
# 18        high
# 19         low
# 20         low
#
# [21 rows x 23 columns]

# %%
df_visual.shape
# Out:
# (21, 23)

# %%
# monthly churn trend [time series kpi]

# %%
df_visual['cancellation_month']=df_visual['cancellation_date'].dt.to_period('M')

# %%
churn_trend=df_visual[df_visual['churn_flag']==1].groupby('cancellation_month').size()
plt.figure(figsize=(8,3))
plt.plot(churn_trend.index.astype('str'),churn_trend.values,color='green', marker='o', linestyle='dashed',   linewidth=2, markersize=12)
plt.title('Monthly Churn Trend')
plt.xlabel('Month')
plt.ylabel('Churned Customers')
plt.show()

# %%
#churn by plan type

# %%
df_visual.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                    None
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                    None
# 3   Premium        Annual               NaT                    None
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  ...        state  gender        dob complaint_date  \
# 0            13.99   627  ...  Maharashtra    Male 1982-04-12            NaT
# 1            12.99  1150  ...    Karnataka    Male 1995-11-23     2024-08-28
# 2             6.99   210  ...        Delhi  Female 1978-02-15            NaT
# 3            22.99  1725  ...     Nagaland    Male 2001-08-30            NaT
# 4            13.99   195  ...        Delhi  Female 1990-05-05     2024-01-20
#
#   escalations csat_score complaint_count tenure_days  churn_risk  \
# 0           0        NaN             NaN      1957.0         low
# 1           1       10.0             2.0      1501.0        high
# 2           0        NaN             NaN      1342.0         low
# 3           0        NaN             NaN      2632.0         low
# 4           1       20.0             1.0       419.0        high
#
#    cancellation_month
# 0                 NaT
# 1             2024-09
# 2                 NaT
# 3                 NaT
# 4             2024-02
#
# [5 rows x 24 columns]

# %%
churn_plan = df_visual.groupby('plan_type')['churn_flag'].mean()
#colors=['yellow','purple','red']
plt.figure(figsize=(7,4))
plt.bar(churn_plan.index, churn_plan.values)
plt.xlabel('Plan Type')
plt.ylabel('Churned Customers')
plt.title('Churn by plan type')
plt.show()

# %%
#churn by states
churn_plan = df_visual.groupby('state')['churn_flag'].mean()
#colors=['yellow','purple','red']
plt.figure(figsize=(15,4))
plt.bar(churn_plan.index, churn_plan.values)
plt.xlabel('State')
plt.ylabel('Churned Customers')
plt.title('Churn by State')
plt.show()

# %%
#visualisation using seaborn 
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk', 'cancellation_month'],
#       dtype='object')

# %%
#wrong way of encoding as number are not based on priority 

df_encoded= df_visual[['plan_type','contract_type','churn_score','churn_flag','churn_risk','escalations']].head()


categorical_cols=['plan_type','contract_type','churn_risk']

for col in categorical_cols:
    df_encoded[col]=df_encoded[col].astype('category').cat.codes

# %%
df_encoded.head()
# Out:
#    plan_type  contract_type  churn_score  churn_flag  churn_risk  escalations
# 0          2              0           12           0           1            0
# 1          1              0           91           1           0            1
# 2          0              1           34           0           1            0
# 3          1              0            8           0           1            0
# 4          2              1           88           1           0            1

# %%
#heatmap
sns.heatmap(df_encoded.corr(),annot=True)
# Out:
# <Axes: >

# %%
df_encoded
# Out:
#    plan_type  contract_type  churn_score  churn_flag  churn_risk  escalations
# 0          2              0           12           0           1            0
# 1          1              0           91           1           0            1
# 2          0              1           34           0           1            0
# 3          1              0            8           0           1            0
# 4          2              1           88           1           0            1

# %%
#correct  method of encoding based on priority 

df_encoded= df_visual[['plan_type','contract_type','churn_score','churn_flag','churn_risk','escalations']].head()


order_mapping={'plan_type':['Basic','Standard','Premium']
               ,'contract_type':['Monthly','Annual']

,'churn_risk':['low','med','high']}

for col,order in order_mapping.items():
    df_encoded[col]=pd.Categorical(df_encoded[col].astype('category'),categories=order,ordered=True).codes

# %%
df_encoded.head()
# Out:
#    plan_type  contract_type  churn_score  churn_flag  churn_risk  escalations
# 0          1              1           12           0           0            0
# 1          2              1           91           1           2            1
# 2          0              0           34           0           0            0
# 3          2              1            8           0           0            0
# 4          1              0           88           1           2            1

# %%
sns.heatmap(df_encoded.corr(),annot=True)
# Out:
# <Axes: >

# %%
#pairplot

# %%
sns.pairplot(df_encoded)

# %%
#carplot-multi dim comparison

# %%
sns.catplot(data=df_visual,
    
    x='plan_type',
    y='monthly_charges',
    hue='gender',
    row=None,
    col='churn_risk')

# %%
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk', 'cancellation_month'],
#       dtype='object')

# %%
#pivot table

# %%
pd.pivot_table(df_visual,
              values='churn_flag',
               index='plan_type',
               aggfunc='mean'
              
              ).reset_index()
# Out:
#   plan_type  churn_flag
# 0     Basic    0.600000
# 1   Premium    0.142857
# 2  Standard    0.222222

# %%
pd.pivot_table(df_visual, index='plan_type',
              values=['churn_flag','monthly_charges','customerid'],
              
               aggfunc={

                   'churn_flag':'mean',
                   'monthly_charges':'sum',
                   'customerid':'nunique'
               }
              
              )
# Out:
#            churn_flag  customerid  monthly_charges
# plan_type
# Basic        0.600000           5            52.95
# Premium      0.142857           7           218.93
# Standard     0.222222           9           123.91
